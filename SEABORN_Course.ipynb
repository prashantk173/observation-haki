# %% [markdown]
# #**Seaborn**

# %% [markdown]
# #*Importing*

# %%
import seaborn as sns
#%matplotlib inline

# %% [markdown]
# #*Distribution Plots*

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# DISTPLOT - Distribution Plot - Histogram

# %%
sns.distplot(tips['total_bill']) #creating a plotwiththe line.

# %%
sns.distplot(tips['total_bill'],kde = False) 
#uise kde=false for the line to be removed an make a proper histogram.

# %%
# didt plot = distributionplot using the bin size to determine the density.
sns.distplot(tips['total_bill'],kde = False, bins=30)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#if the bin size is increased we can see the plot for every instance.
sns.distplot(tips['total_bill'],kde = False, bins=100)

# %% [markdown]
# JOINTPLOT - combination of two dist plots.

# %%
sns.jointplot(x='total_bill',y='tip',data=tips) 
# ajoint plot with two different attributes giving a scatter plot.

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex') #determining the kind of the plot.

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg') #linear regresssion

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='kde') #density plot

# %% [markdown]
# PAIRPLOTS -
# making plots for all the data in the datset , by using all the jont plots together.

# %%
sns.pairplot(tips) #pairplot with all the relations possible
#we can see histograms for the same vs same plots.

# %%
# adding hue and pallette fn. to determine categories.
sns.pairplot(tips,hue='sex',palette='coolwarm') #We will do customization later.

# %% [markdown]
# RUGPLOT
# Similar to distplot but, here it is the determination of the kde plot or the density plot

# %%
sns.rugplot(tips['total_bill'])

# %%
# Don't worry about understanding this code!
# It's just for the diagram below
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

#Create dataset
dataset = np.random.randn(25)

# Create another rugplot
sns.rugplot(dataset);

# Set up the x-axis for the plot
x_min = dataset.min() - 2
x_max = dataset.max() + 2

# 100 equally spaced points from x_min to x_max
x_axis = np.linspace(x_min,x_max,100)

# Set up the bandwidth, for info on this:
url = 'http://en.wikipedia.org/wiki/Kernel_density_estimation#Practical_estimation_of_the_bandwidth'

bandwidth = ((4*dataset.std()**5)/(3*len(dataset)))**.2


# Create an empty kernel list
kernel_list = []

# Plot each basis function
for data_point in dataset:
    
    # Create a kernel for each point and append to list
    kernel = stats.norm(data_point,bandwidth).pdf(x_axis)
    kernel_list.append(kernel)
    
    #Scale for plotting
    kernel = kernel / kernel.max()
    kernel = kernel * .4
    plt.plot(x_axis,kernel,color = 'grey',alpha=0.5)

plt.ylim(0,1)
# Out:
# (0, 1)

# %%
# To get the kde plot we can sum these basis functions.

# Plot the sum of the basis function
sum_of_kde = np.sum(kernel_list,axis=0)

# Plot figure
fig = plt.plot(x_axis,sum_of_kde,color='indianred')

# Add the initial rugplot
sns.rugplot(dataset,c = 'indianred')

# Get rid of y-tick marks
plt.yticks([])

# Set title
plt.suptitle("Sum of the Basis Functions")

# %% [markdown]
# KDEPLOT

# %%
sns.kdeplot(tips['total_bill'])

# %% [markdown]
# #*Categorial Plots*

# %%
import seaborn as sns
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# BARPLOT

# %%
sns.barplot(x='sex',y='total_bill',data=tips) #x should be a categorical data and the y needs to be a numerical data.

# %%
sns.barplot(x='sex',y='total_bill',data=tips, estimator= np.std) # here the estimator is used to det mean, sd, var, etc statistical fn.s

# %%
sns.barplot(x='size',y='total_bill',data=tips)

# %% [markdown]
# COUNTPLOT - Explicitly only counts the categorical data

# %%
sns.countplot(x='sex',data=tips)

# %% [markdown]
# BOXPLOT

# %%
sns.boxplot(x='day',y='total_bill',data=tips)

# %%
# using hue fn.to further subcategorise.
sns.boxplot(x='day',y='total_bill',data=tips,hue='smoker',palette = 'coolwarm')

# %%
sns.boxplot(x='day',y='total_bill',data=tips)

# %% [markdown]
# VIOLIN PLOTS

# %%
sns.violinplot(x='day',y='total_bill',data=tips)

# %%
sns.violinplot(x='day',y='total_bill',data=tips,hue='smoker',palette='coolwarm')

# %%
#using split fn.to fit both categories in one.
sns.violinplot(x='day',y='total_bill',data=tips, split=True,hue='sex')

# %% [markdown]
# SRIPPLOT

# %%
sns.stripplot(x='day',y='total_bill',data=tips) #here it is a scatter plot with one value to be categorical.

# %%
#using jitter fn. to arrange the data
sns.stripplot(x='day',y='total_bill',data=tips,jitter=False)

# %%
#adding hue arguments and split argument
sns.stripplot(x='day',y='total_bill',data=tips,hue='sex',split=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:2805: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# SWARMPLOT

# %%
sns.swarmplot(x='day',y='total_bill',data=tips) #combination of strp and violin plots, representation of the dat with no overlapping.

# %%
sns.swarmplot(x='day',y='total_bill',data=tips,hue='sex',split=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3002: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 5.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# the `split` parameter has been renamed to `dodge`

# %%
#plotting violin and swarm both togeteher giving good representation.
sns.violinplot(x='day',y='total_bill',data=tips)
sns.swarmplot(x='day',y='total_bill',data=tips, color='black')

# %% [markdown]
# FACTORPLOT

# %%
sns.factorplot(x='day',y='total_bill',data=tips,kind='bar') 
#from this we can call any plot by using the kind fn.
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
#The `factorplot` function has been renamed to `catplot`.

# %% [markdown]
# #*Matrix Plots*

# %%
import seaborn as sns
import numpy as np
import pandas as pd

tips = sns.load_dataset('tips')
flights = sns.load_dataset('flights')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %% [markdown]
# HEATMAP - requires a matrix data to make the plot

# %%
# the data is correlated to be a matrix and then the heat map is made.
tc= tips.corr()

# %%
tc #this is in matrix form
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tc)

# %%
# for annotations and coloemap
sns.heatmap(tc,annot=True,cmap='coolwarm')

# %%
#using pivot tables to create the matrices.

# %%
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
fm = flights.pivot_table(index='month',columns='year',values='passengers')

# %%
fm
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(fm)

# %%
#using cmap and arguments.
sns.heatmap(fm,cmap='magma',linecolor='white',linewidths=1)

# %%
sns.clustermap(fm,standard_scale=1,cmap='coolwarm') 
#specifies the similarities between the data, and we can see that they are arranged in random to accomodate the similarities.

# %% [markdown]
# #**Grids**

# %%
import seaborn as sns
import pandas as pd
import numpy as np

iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.pairplot(iris)

# %% [markdown]
# PAIRGRID

# %%
sns.PairGrid(iris) #this gives a empty grids for us to execute our plots.

# %%
g = sns.PairGrid(iris)
g.map(sns.scatterplot)

# %%
g.map_diag(sns.rugplot)
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot)

# %% [markdown]
# FACETGRID

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
t = sns.FacetGrid(data=tips,row='time',col='smoker')
t.map(sns.distplot,'total_bill')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
t = sns.FacetGrid(data=tips,row='time',col='smoker')
t.map(sns.scatterplot,'total_bill','tip')

# %% [markdown]
# REGRESSION PLOTS

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot(x='total_bill',y='tip',data=tips)

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex')

# %%
#giving markers
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',markers=['o','v'])

# %%
#to increase the size of the markers
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',markers=['o','v'], scatter_kws={'s':100})

# %%
# to have grids rather than hue
sns.lmplot(x='total_bill',y='tip',data=tips,col='sex',row='time')

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='day',hue='sex')

# %%
#giving the aspect ratio
sns.lmplot(x='total_bill',y='tip',data=tips,col='sex',row='time',aspect=0.6,size=8)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# The `size` parameter has been renamed to `height`; please update your code.

# %% [markdown]
# STYLE and COLOR
